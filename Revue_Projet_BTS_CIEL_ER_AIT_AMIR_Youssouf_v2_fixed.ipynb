# %% [markdown]
# # Revue de Projet BTS CIEL ER – Instrumentation Banc d'Essai RC
# **AIT AMIR Youssouf & DUCHATEAU Édouard** | Encadrants : M. BEAU – Partenaire : PVRC Mini RC de Marigny

# %% [markdown]
# ## ① — Présentation
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ② — Sommaire
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ③ — Contexte & identification du besoin
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ④ — Cas d'utilisation
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑤ — Architecture du système
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑥ — Matériel du projet
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑦ — Capteurs de mesure
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑧ — Module NFC/RFID – Mise en œuvre
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑨ — Serveur Raspberry Pi – Stack LAMP
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑩ — Interface web – Contrôle d'accès NFC
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑪ — Base de données MariaDB
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑫ — Réseau & VPN Tailscale
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑬ — Développement logiciel
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑭ — Phase de consolidation avant l'oral
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑮ — Difficultés rencontrées & solutions
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑯ — Diagramme des exigences
#
# <img src="data:image/png;base64,..." style="width:100%; max-width:900px; display:block; margin:auto;"/>

# %% [markdown]
# ## ⑰ — Conclusion
#
# <img src="data:image/jpeg;base64,..." style="width:100%; display:block; margin:auto;"/>
