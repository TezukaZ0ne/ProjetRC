# %% [markdown]
# # Revue de Projet BTS CIEL ER – Instrumentation Banc d'Essai RC
# **AIT AMIR Youssouf & DUCHATEAU Édouard** | Encadrants : M. BEAU – Partenaire : PVRC Mini RC de Marigny

# %% [markdown]
# ## 📋 Sommaire
#
# | N° | Section |
# |----|---------|
# | **01.** | Contexte & identification du besoin |
# | **02.** | Architecture du système |
# | **03.** | Matériel du projet |
# | **04.** | Module NFC/RFID – Mise en œuvre |
# | **05.** | Serveur Raspberry Pi (LAMP) |
# | **06.** | Réseau & VPN Tailscale |
# | **07.** | Développement logiciel |
# | **08.** | Module A6 – GSM & Alertes |
# | **09.** | Difficultés rencontrées & solutions |
# | **10.** | Diagramme des exigences |

# %% [markdown]
# ![Slide 1 – Page de garde](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 2 – Sommaire](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 3 – 01. Contexte & identification du besoin](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 4 – 01. Cas d'utilisation](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 5 – 02. Architecture du système](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 6 – 03. Matériel du projet](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 7 – 03. Capteurs de mesure](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 8 – 04. Module NFC/RFID – Mise en œuvre](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 9 – 05. Serveur Raspberry Pi – Stack LAMP](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 10 – 05. Interface web – Contrôle d'accès NFC](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 11 – 05. Base de données MariaDB](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 12 – 05. Tableau de bord PHP](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 13 – 06. Réseau & VPN Tailscale](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 14 – 07. Développement logiciel](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 15 – 08. Module A6 – GSM & Alertes](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 16 – 09. Difficultés rencontrées & solutions](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 17 – Phase de consolidation avant l'oral](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 18 – 10. Diagramme des exigences](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 19 – Conclusion](data:image/jpeg;base64,...)
