# %% [markdown]
# # Revue de Projet BTS CIEL ER – Instrumentation Banc d'Essai RC
# **AIT AMIR Youssouf & DUCHATEAU Édouard** | Encadrants : M. BEAU – Partenaire : PVRC Mini RC de Marigny

# %% [markdown]
# ![Slide 1](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 2](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 3](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 4](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 5](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 6](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 7](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 8](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 9](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 10](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 11](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 12](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 13](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 14](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 15](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 16](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide 17](data:image/jpeg;base64,...)
